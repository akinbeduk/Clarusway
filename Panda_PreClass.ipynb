# %% [markdown]
# <a href="https://colab.research.google.com/github/AkinDS/DataScience/blob/main/Panda_PreClass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
series=pd.Series(('Nik','Fury','Captain','America',175))
series
# Out:
# 0        Nik
# 1       Fury
# 2    Captain
# 3    America
# 4        175
# dtype: object

# %%
dataframe1=pd.DataFrame([('Nick','Fury','Captain','America',175),('Black','Panther','Captain','Marvel',165)],columns=['First Name','Last Name', 'First Name', 'Last Name', 'Ratings'])
dataframe1
# Out:
#   First Name Last Name First Name Last Name  Ratings
# 0       Nick      Fury    Captain   America      175
# 1      Black   Panther    Captain    Marvel      165

# %%
dataframe2=pd.DataFrame({'First Name':['Nick', 'Black'],'Last Name':['Fury','Panther'],'Ratings':[175,165]})
dataframe2
# Out:
#   First Name Last Name  Ratings
# 0       Nick      Fury      175
# 1      Black   Panther      165

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.shape #Satır ve sütun sayısı
# Out:
# (244, 7)

# %%
tips.head(5) #İlk 5 değeri göstermek için
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail(5) #Son 5 değeri göstermek için
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.set_index('total_bill')
# Out:
#              tip     sex smoker   day    time  size
# total_bill
# 16.99       1.01  Female     No   Sun  Dinner     2
# 10.34       1.66    Male     No   Sun  Dinner     3
# 21.01       3.50    Male     No   Sun  Dinner     3
# 23.68       3.31    Male     No   Sun  Dinner     2
# 24.59       3.61  Female     No   Sun  Dinner     4
# ...          ...     ...    ...   ...     ...   ...
# 29.03       5.92    Male     No   Sat  Dinner     3
# 27.18       2.00  Female    Yes   Sat  Dinner     2
# 22.67       2.00    Male    Yes   Sat  Dinner     2
# 17.82       1.75    Male     No   Sat  Dinner     2
# 18.78       3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
tips.tip
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
tips['tip']
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
tips.loc[239] #Location fonksiyonu
# Out:
# total_bill     29.03
# tip             5.92
# sex             Male
# smoker            No
# day              Sat
# time          Dinner
# size               3
# Name: 239, dtype: object

# %%
tips.loc[239,'sex']
# Out:
# 'Male'

# %%
tips.iloc[0] #iLocation satır ve sütun sayısı girilerek datayı getirir.
# Out:
# total_bill     16.99
# tip             1.01
# sex           Female
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 0, dtype: object

# %%
tips.iloc[0,1]
# Out:
# 1.01

# %%
tips.iloc[:5,:]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.iloc[-5:,:]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.iloc[:5,:3]
# Out:
#    total_bill   tip     sex
# 0       16.99  1.01  Female
# 1       10.34  1.66    Male
# 2       21.01  3.50    Male
# 3       23.68  3.31    Male
# 4       24.59  3.61  Female

# %%
tips['tip']=='total_bill'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Name: tip, Length: 244, dtype: bool
